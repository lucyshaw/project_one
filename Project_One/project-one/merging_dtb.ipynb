# %%
import pandas as pd
from sodapy import Socrata

# %%
location_results_df = pd.read_csv("../csv_location/cta_locations.csv")

# %%
location_results_df.head()
# Out:
#    STOP_ID DIRECTION_ID                          STOP_NAME  \
# 0    30161            E                  18th (Loop-bound)
# 1    30162            W           18th (54th/Cermak-bound)
# 2    30022            N           35th/Archer (Loop-bound)
# 3    30023            S         35th/Archer (Midway-bound)
# 4    30213            N  35-Bronzeville-IIT (Harlem-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# ...

# %%
location_results_df.columns
# Out:
# Index(['STOP_ID', 'DIRECTION_ID', 'STOP_NAME', 'STATION_NAME',
#        'STATION_DESCRIPTIVE_NAME', 'MAP_ID', 'ADA', 'RED', 'BLUE', 'G', 'BRN',
#        'P', 'Pexp', 'Y', 'Pnk', 'O', 'Location'],
#       dtype='object')

# %%
location_results_df = location_results_df.drop_duplicates(subset='MAP_ID')

# %%
location_results_df.head()
# Out:
#    STOP_ID DIRECTION_ID                          STOP_NAME  \
# 0    30161            E                  18th (Loop-bound)
# 2    30022            N           35th/Archer (Loop-bound)
# 4    30213            N  35-Bronzeville-IIT (Harlem-bound)
# 6    30245            N                43rd (Harlem-bound)
# 8    30210            S                  47th (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
# 6                  43rd                  43rd (Green Line)   41270  True
# 8                  47th                  47th (Green Line)   41080  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# ...

# %%
monthly_data = pd.read_csv("../csv_location/monthly_data.csv")

# %%
monthly_data.head()
# Out:
#    station_id stationame month_beginning  avg_weekday_rides  \
# 0       40900     Howard      01/01/2001             6233.9
# 1       41190     Jarvis      01/01/2001             1489.1
# 2       40100      Morse      01/01/2001             4412.5
# 3       41300     Loyola      01/01/2001             4664.5
# 4       40760  Granville      01/01/2001             3109.8
#
#    avg_saturday_rides  avg_sunday-holiday_rides  monthtotal
# 0              3814.5                    2408.6      164447
# 1              1054.0                     718.0       40567
# 2              3064.5                    2087.8      119772
# 3              3156.0                    1952.8      125008
# 4              2126.0                    1453.8       84189

# %%
monthly_data = monthly_data.rename(columns={'station_id': 'MAP_ID'})

# %%
monthly_data.columns
# Out:
# Index(['MAP_ID', 'stationame', 'month_beginning', 'avg_weekday_rides',
#        'avg_saturday_rides', 'avg_sunday-holiday_rides', 'monthtotal'],
#       dtype='object')

# %%
new_df = pd.merge(monthly_data, location_results_df, how='left', on='MAP_ID')

# %%
new_df.head()
# Out:
#    MAP_ID stationame month_beginning  avg_weekday_rides  avg_saturday_rides  \
# 0   40900     Howard      01/01/2001             6233.9              3814.5
# 1   41190     Jarvis      01/01/2001             1489.1              1054.0
# 2   40100      Morse      01/01/2001             4412.5              3064.5
# 3   41300     Loyola      01/01/2001             4664.5              3156.0
# 4   40760  Granville      01/01/2001             3109.8              2126.0
#
#    avg_sunday-holiday_rides  monthtotal  STOP_ID DIRECTION_ID  \
# 0                    2408.6      164447  30173.0            N
# 1                     718.0       40567  30227.0            N
# 2                    2087.8      119772  30020.0            N
# 3                    1952.8      125008  30251.0            N
# 4                    1453.8       84189  30148.0            S
#
#                    STOP_NAME           ...              RED   BLUE      G  \
# ...

# %%
newer_df = new_df.drop(['DIRECTION_ID', 'STOP_NAME', 'STATION_NAME', 'STOP_ID', 'STATION_DESCRIPTIVE_NAME', 'ADA', 'Pexp'], axis=1)

# %%
newer_df.head()
# Out:
#    MAP_ID stationame month_beginning  avg_weekday_rides  avg_saturday_rides  \
# 0   40900     Howard      01/01/2001             6233.9              3814.5
# 1   41190     Jarvis      01/01/2001             1489.1              1054.0
# 2   40100      Morse      01/01/2001             4412.5              3064.5
# 3   41300     Loyola      01/01/2001             4664.5              3156.0
# 4   40760  Granville      01/01/2001             3109.8              2126.0
#
#    avg_sunday-holiday_rides  monthtotal   RED   BLUE      G    BRN      P  \
# 0                    2408.6      164447  True  False  False  False  False
# 1                     718.0       40567  True  False  False  False  False
# 2                    2087.8      119772  True  False  False  False  False
# 3                    1952.8      125008  True  False  False  False  False
# 4                    1453.8       84189  True  False  False  False  False
#
#        Y    Pnk      O                 Location
# ...

# %%
newer_df.to_csv('../csv_location/newer_csv')
