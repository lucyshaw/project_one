# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
csv_file = 'cta_ridership_historical.csv'
cta_data_df = pd.read_csv(csv_file)

cta_data_df.head(20)
# Out:
#    service_date day_type      bus  rail_boardings  total_rides
# 0        1/1/01        U   297192          126455       423647
# 1        1/2/01        W   780827          501952      1282779
# 2        1/3/01        W   824923          536432      1361355
# 3        1/4/01        W   870021          550011      1420032
# 4        1/5/01        W   890426          557917      1448343
# 5        1/6/01        A   577401          255356       832757
# 6        1/7/01        U   375831          169825       545656
# 7        1/8/01        W   985221          590706      1575927
# 8        1/9/01        W   978377          599905      1578282
# 9       1/10/01        W   984884          602052      1586936
# 10      1/11/01        W   995561          607503      1603064
# 11      1/12/01        W  1018985          605252      1624237
# 12      1/13/01        A   591791          270056       861847
# 13      1/14/01        U   373091          174842       547933
# 14      1/15/01        W   675845          412149      1087994
# 15      1/16/01        W  1024367          622163      1646530
# 16      1/17/01        W  1018690          620343      1639033
# 17      1/18/01        W  1006996          618832      1625828
# 18      1/19/01        W   909964          583851      1493815
# 19      1/20/01        A   582348          263815       846163

# %%
url="http://api.openweathermap.org/data/2.5/weather?q=Chicago"+ "&APPID=" +"99e15d2a53b3bedd876f9ea0f6b7ad30"
chicagoweather=requests.get(url).json()
chicagoweather
# Out:
# {'coord': {'lon': -87.62, 'lat': 41.88},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 268.34,
#   'pressure': 1029,
#   'humidity': 65,
#   'temp_min': 265.95,
#   'temp_max': 271.15},
#  'visibility': 16093,
#  'wind': {'speed': 1.5, 'deg': 200},
#  'clouds': {'all': 90},
#  'dt': 1547168100,
#  'sys': {'type': 1,
#   'id': 4861,
#   'message': 0.0114,
#   'country': 'US',
#   'sunrise': 1547212631,
#   'sunset': 1547246393},
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
#Rail Ridership Over the Years
rail_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_railriders=cta2001["rail_boardings"].sum()
rail_byyear.append(cta2001_railriders)

cta2002=cta_data_df[365:730]
cta2002_railriders=cta2002["rail_boardings"].sum()
rail_byyear.append(cta2002_railriders)


cta2003=cta_data_df[730:1095]
cta2003_railriders=cta2003["rail_boardings"].sum()
rail_byyear.append(cta2003_railriders)

cta2004=cta_data_df[1095:1461]
cta2004_railriders=cta2004["rail_boardings"].sum()
rail_byyear.append(cta2004_railriders)


cta2005=cta_data_df[1461:1826]
cta2005_railriders=cta2005["rail_boardings"].sum()
rail_byyear.append(cta2005_railriders)

cta2006=cta_data_df[1826:2191]
cta2006_railriders=cta2006["rail_boardings"].sum()
rail_byyear.append(cta2006_railriders)

cta2007=cta_data_df[2191:2556]
cta2007_railriders=cta2007["rail_boardings"].sum()
rail_byyear.append(cta2007_railriders)

cta2008=cta_data_df[2556:2922]
cta2008_railriders=cta2008["rail_boardings"].sum()
rail_byyear.append(cta2008_railriders)

cta2009=cta_data_df[2922:3287]
cta2009_railriders=cta2009["rail_boardings"].sum()
rail_byyear.append(cta2009_railriders)

cta2010=cta_data_df[3287:3652]
cta2010_railriders=cta2010["rail_boardings"].sum()
rail_byyear.append(cta2010_railriders)

cta2011=cta_data_df[3652:4048]
cta2011_railriders=cta2011["rail_boardings"].sum()
rail_byyear.append(cta2011_railriders)


cta2012=cta_data_df[4048:4414]
cta2012_railriders=cta2012["rail_boardings"].sum()
rail_byyear.append(cta2012_railriders)


cta2013=cta_data_df[4414:4779]
cta2013_railriders=cta2013["rail_boardings"].sum()
rail_byyear.append(cta2013_railriders)

cta2014=cta_data_df[4779:5175]
cta2014_railriders=cta2014["rail_boardings"].sum()
rail_byyear.append(cta2014_railriders)


cta2015=cta_data_df[5175:5540]
cta2015_railriders=cta2015["rail_boardings"].sum()
rail_byyear.append(cta2015_railriders)

cta2016=cta_data_df[5540:5906]
cta2016_railriders=cta2016["rail_boardings"].sum()
rail_byyear.append(cta2016_railriders)

cta2017=cta_data_df[5906:6271]
cta2017_railriders=cta2017["rail_boardings"].sum()
rail_byyear.append(cta2017_railriders)

x_axis=np.arange(0,len(rail_byyear))
x_years=["2001", "2002", "2003","2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012","2013", "2014", "2015", "2016", "2017"]

# %%
#Bus Ridership Over the Years
bus_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_busriders=cta2001["bus"].sum()
bus_byyear.append(cta2001_busriders)

cta2002=cta_data_df[365:730]
cta2002_busriders=cta2002["bus"].sum()
bus_byyear.append(cta2002_busriders)


cta2003=cta_data_df[730:1095]
cta2003_busriders=cta2003["bus"].sum()
bus_byyear.append(cta2003_busriders)

cta2004=cta_data_df[1095:1461]
cta2004_busriders=cta2004["bus"].sum()
bus_byyear.append(cta2004_busriders)


cta2005=cta_data_df[1461:1826]
cta2005_busriders=cta2005["bus"].sum()
bus_byyear.append(cta2005_busriders)

cta2006=cta_data_df[1826:2191]
cta2006_busriders=cta2006["bus"].sum()
bus_byyear.append(cta2006_busriders)

cta2007=cta_data_df[2191:2556]
cta2007_busriders=cta2007["bus"].sum()
bus_byyear.append(cta2007_busriders)

cta2008=cta_data_df[2556:2922]
cta2008_busriders=cta2008["bus"].sum()
bus_byyear.append(cta2008_busriders)

cta2009=cta_data_df[2922:3287]
cta2009_busriders=cta2009["bus"].sum()
bus_byyear.append(cta2009_busriders)

cta2010=cta_data_df[3287:3652]
cta2010_busriders=cta2010["bus"].sum()
bus_byyear.append(cta2010_busriders)

cta2011=cta_data_df[3652:4048]
cta2011_busriders=cta2011["bus"].sum()
bus_byyear.append(cta2011_busriders)


cta2012=cta_data_df[4048:4414]
cta2012_busriders=cta2012["bus"].sum()
bus_byyear.append(cta2012_busriders)


cta2013=cta_data_df[4414:4779]
cta2013_busriders=cta2013["bus"].sum()
bus_byyear.append(cta2013_busriders)

cta2014=cta_data_df[4779:5175]
cta2014_busriders=cta2014["bus"].sum()
bus_byyear.append(cta2014_busriders)


cta2015=cta_data_df[5175:5540]
cta2015_busriders=cta2015["bus"].sum()
bus_byyear.append(cta2015_busriders)

cta2016=cta_data_df[5540:5906]
cta2016_busriders=cta2016["bus"].sum()
bus_byyear.append(cta2016_busriders)

cta2017=cta_data_df[5906:6271]
cta2017_busriders=cta2017["bus"].sum()
bus_byyear.append(cta2017_busriders)

# %%
totalriders_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_totalriders=cta2001["total_rides"].sum()
totalriders_byyear.append(cta2001_totalriders)

cta2002=cta_data_df[365:730]
cta2002_totalriders=cta2002["total_rides"].sum()
totalriders_byyear.append(cta2002_totalriders)


cta2003=cta_data_df[730:1095]
cta2003_totalriders=cta2003["total_rides"].sum()
totalriders_byyear.append(cta2003_totalriders)

cta2004=cta_data_df[1095:1461]
cta2004_totalriders=cta2004["total_rides"].sum()
totalriders_byyear.append(cta2004_totalriders)


cta2005=cta_data_df[1461:1826]
cta2005_totalriders=cta2005["total_rides"].sum()
totalriders_byyear.append(cta2005_totalriders)

cta2006=cta_data_df[1826:2191]
cta2006_totalriders=cta2006["total_rides"].sum()
totalriders_byyear.append(cta2006_totalriders)

cta2007=cta_data_df[2191:2556]
cta2007_totalriders=cta2007["total_rides"].sum()
totalriders_byyear.append(cta2007_totalriders)

cta2008=cta_data_df[2556:2922]
cta2008_totalriders=cta2008["total_rides"].sum()
totalriders_byyear.append(cta2008_totalriders)

cta2009=cta_data_df[2922:3287]
cta2009_totalriders=cta2009["total_rides"].sum()
totalriders_byyear.append(cta2009_totalriders)

cta2010=cta_data_df[3287:3652]
cta2010_totalriders=cta2010["total_rides"].sum()
totalriders_byyear.append(cta2010_totalriders)

cta2011=cta_data_df[3652:4048]
cta2011_totalriders=cta2011["total_rides"].sum()
totalriders_byyear.append(cta2011_totalriders)


cta2012=cta_data_df[4048:4414]
cta2012_totalriders=cta2012["total_rides"].sum()
totalriders_byyear.append(cta2012_totalriders)


cta2013=cta_data_df[4414:4779]
cta2013_totalriders=cta2013["total_rides"].sum()
totalriders_byyear.append(cta2013_totalriders)

cta2014=cta_data_df[4779:5175]
cta2014_totalriders=cta2014["total_rides"].sum()
totalriders_byyear.append(cta2014_totalriders)


cta2015=cta_data_df[5175:5540]
cta2015_totalriders=cta2015["total_rides"].sum()
totalriders_byyear.append(cta2015_totalriders)

cta2016=cta_data_df[5540:5906]
cta2016_totalriders=cta2016["total_rides"].sum()
totalriders_byyear.append(cta2016_totalriders)

cta2017=cta_data_df[5906:6271]
cta2017_totalriders=cta2017["total_rides"].sum()
totalriders_byyear.append(cta2017_totalriders)

total, =plt.plot(x_axis, totalriders_byyear, color="red", label="total")
bus,=plt.plot(x_axis, bus_byyear, color="blue", label="bus")
rail, =plt.plot(x_axis, rail_byyear, color="green",label="rail")
plt.xticks(x_axis,x_years, rotation ="vertical")
plt.title("CTA Ridership Over the Years")
plt.legend(handles= [total, bus, rail], loc="upper left")

# %%
x_axis = cta_data_df['day_type']

plt.bar(x_axis, cta_data_df['total_rides'])
plt.show()

# %%
csv_file = 'newer.csv'
cta_month = pd.read_csv(csv_file)

red=cta_month.loc[cta_month["RED"]==True]
blue=cta_month.loc[cta_month["BLUE"]==True]
green=cta_month.loc[cta_month["G"]==True]
brown=cta_month.loc[cta_month["BRN"]==True]
yellow=cta_month.loc[cta_month["Y"]==True]
pink=cta_month.loc[cta_month["P"]==True]
orange=cta_month.loc[cta_month["O"]==True]

# %%
red
# Out:
#        Unnamed: 0  MAP_ID          stationame month_beginning  \
# 0               0   40900              Howard      01/01/2001
# 1               1   41190              Jarvis      01/01/2001
# 2               2   40100               Morse      01/01/2001
# 3               3   41300              Loyola      01/01/2001
# 4               4   40760           Granville      01/01/2001
# 5               5   40880           Thorndale      01/01/2001
# 6               6   41380           Bryn Mawr      01/01/2001
# 7               7   40340              Berwyn      01/01/2001
# 8               8   41200              Argyle      01/01/2001
# 9               9   40770            Lawrence      01/01/2001
# 10             10   40540              Wilson      01/01/2001
# 11             11   40080            Sheridan      01/01/2001
# 12             12   41420  Addison-North Main      01/01/2001
# 14             14   41220           Fullerton      01/01/2001
# 15             15   40650      North/Clybourn      01/01/2001
# 16             16   40630      Clark/Division      01/01/2001
# 17             17   41450       Chicago/State      01/01/2001
# 18             18   40330         Grand/State      01/01/2001
# 19             19   41660          Lake/State      01/01/2001
# 21             21   41090        Monroe/State      01/01/2001
# 22             22   40560       Jackson/State      01/01/2001
# 23             23   41490            Harrison      01/01/2001
# 25             25   41000    Cermak-Chinatown      01/01/2001
# 26             26   40190   Sox-35th-Dan Ryan      01/01/2001
# 27             27   41230       47th-Dan Ryan      01/01/2001
# 28             28   41170   Garfield-Dan Ryan      01/01/2001
# 29             29   40910       63rd-Dan Ryan      01/01/2001
# 30             30   40990                69th      01/01/2001
# 31             31   40240                79th      01/01/2001
# 32             32   41430                87th      01/01/2001
# ...           ...     ...                 ...             ...
# 30292       30292   41430                87th      09/01/2018
# 30293       30293   40240                79th      09/01/2018
# 30294       30294   40990                69th      09/01/2018
# 30295       30295   40910       63rd-Dan Ryan      09/01/2018
# 30296       30296   41170   Garfield-Dan Ryan      09/01/2018
# 30297       30297   41230       47th-Dan Ryan      09/01/2018
# 30298       30298   40190   Sox-35th-Dan Ryan      09/01/2018
# 30299       30299   41000    Cermak-Chinatown      09/01/2018
# 30301       30301   41490            Harrison      09/01/2018
# 30302       30302   40560       Jackson/State      09/01/2018
# 30303       30303   41090        Monroe/State      09/01/2018
# 30304       30304   41660          Lake/State      09/01/2018
# 30305       30305   40330         Grand/State      09/01/2018
# 30306       30306   41450       Chicago/State      09/01/2018
# 30307       30307   40630      Clark/Division      09/01/2018
# 30308       30308   40650      North/Clybourn      09/01/2018
# 30309       30309   41220           Fullerton      09/01/2018
# 30311       30311   41420  Addison-North Main      09/01/2018
# 30312       30312   40080            Sheridan      09/01/2018
# 30313       30313   40540              Wilson      09/01/2018
# 30314       30314   40770            Lawrence      09/01/2018
# 30315       30315   41200              Argyle      09/01/2018
# 30316       30316   40340              Berwyn      09/01/2018
# 30317       30317   41380           Bryn Mawr      09/01/2018
# 30318       30318   40880           Thorndale      09/01/2018
# 30319       30319   40760           Granville      09/01/2018
# 30320       30320   41300              Loyola      09/01/2018
# 30321       30321   40100               Morse      09/01/2018
# 30322       30322   41190              Jarvis      09/01/2018
# 30323       30323   40900              Howard      09/01/2018
#
#        avg_weekday_rides  avg_saturday_rides  avg_sunday-holiday_rides  \
# 0                 6233.9              3814.5                    2408.6
# 1                 1489.1              1054.0                     718.0
# 2                 4412.5              3064.5                    2087.8
# 3                 4664.5              3156.0                    1952.8
# 4                 3109.8              2126.0                    1453.8
# 5                 2977.7              1840.3                    1262.6
# 6                 4425.4              2708.3                    1881.2
# 7                 3329.6              2050.8                    1445.6
# 8                 2745.5              1874.5                    1268.2
# 9                 2689.6              1869.0                    1227.8
# 10                4968.1              3069.0                    1903.8
# 11                4455.9              2625.8                    1685.2
# 12                4805.5              2893.5                    1900.2
# 14               10121.0              5239.8                    3116.2
# 15                3525.6              2674.5                    1772.8
# 16                6501.5              4726.5                    3209.0
# 17               12311.0              9184.3                    5658.6
# 18                8378.5              5428.0                    3504.8
# 19               13360.8              5721.8                    3575.8
# 21                7123.0              2439.3                    1269.2
# 22               11340.2              3649.0                    1877.6
# 23                2384.7              1208.3                     715.4
# 25                2396.3              2349.8                    2066.6
# 26                3431.9              2124.3                    1491.6
# 27                2297.6              1594.3                    1121.2
# 28                4510.2              3181.5                    1879.4
# 29                3631.5              2414.8                    1817.8
# 30                6818.6              4519.8                    2901.0
# 31                7406.7              4689.5                    3187.6
# 32                5341.1              3239.3                    2031.6
# ...                  ...                 ...                       ...
# 30292             4282.7              3000.6                    2351.5
# 30293             7049.1              4914.6                    3928.7
# 30294             5148.4              3818.0                    2860.0
# 30295             3296.1              2469.0                    1981.5
# 30296             3451.9              2500.8                    1912.5
# 30297             3190.1              2247.8                    1669.2
# 30298             5233.8              4677.8                    4020.0
# 30299             4593.4              5114.6                    3945.5
# 30301             4735.5              3430.2                    2312.8
# 30302            10954.1              4136.0                    2721.8
# 30303            11473.7              4679.0                    3102.5
# 30304            23788.8             14041.4                    9446.8
# 30305            12157.4             11253.4                    8067.0
# 30306            15922.0             12087.4                    8473.2
# 30307             8573.0              6556.4                    4725.7
# 30308             5880.0              4867.4                    3410.7
# 30309            16205.8              9183.8                    6605.0
# 30311            11108.1             10823.6                    6991.2
# 30312             6112.4              3615.6                    2504.5
# 30313             7586.2              4848.8                    3360.8
# 30314             3495.9              2653.6                    1845.2
# 30315             3446.3              2569.2                    2039.5
# 30316             3740.2              2570.4                    1893.5
# 30317             5345.1              3486.8                    2600.2
# 30318             3516.4              2180.2                    1627.7
# 30319             4585.2              3708.8                    2597.8
# 30320             6486.5              5510.0                    3633.5
# 30321             4857.8              3496.6                    2769.3
# 30322             1685.5              1314.0                     981.8
# 30323             5826.0              3966.0                    2982.5
#
#        monthtotal   RED   BLUE      G    BRN      P      Y    Pnk      O  \
# 0          164447  True  False  False  False  False  False  False  False
# 1           40567  True  False  False  False  False  False  False  False
# 2          119772  True  False  False  False  False  False  False  False
# 3          125008  True  False  False  False  False  False  False  False
# 4           84189  True  False  False  False  False  False  False  False
# 5           79184  True  False  False  False  False  False  False  False
# 6          117597  True  False  False  False  False  False  False  False
# 7           88683  True  False  False  False  False  False  False  False
# 8           74240  True  False  False  False  False  False  False  False
# 9           72786  True  False  False  False  False  False  False  False
# 10         131094  True  False  False  False  False  False  False  False
# 11         116958  True  False  False  False  False  False  False  False
# 12         126797  True  False  False  False  False  False  False  False
# 14         259203  True  False  False  False  False  False  False  False
# 15          97126  True  False  False  False  False  False  False  False
# 16         177985  True  False  False  False  False  False  False  False
# 17         335872  True  False  False  False  False  False  False  False
# 18         223562  True  False  False  False  False  False  False  False
# 19         334704  True  False  False  False  False  False  False  False
# 21         172809  True  False  False  False  False  False  False  False
# 22         273468  True  False  False  False  False  False  False  False
# 23          60874  True  False  False  False  False  False  False  False
# 25          72450  True  False  False  False  False  False  False  False
# 26          91457  True  False  False  False  False  False  False  False
# 27          62530  True  False  False  False  False  False  False  False
# 28         121347  True  False  False  False  False  False  False  False
# 29          98640  True  False  False  False  False  False  False  False
# 30         182594  True  False  False  False  False  False  False  False
# 31         197643  True  False  False  False  False  False  False  False
# 32         140619  True  False  False  False  False  False  False  False
# ...           ...   ...    ...    ...    ...    ...    ...    ...    ...
# 30292      110484  True  False  False  False  False  False  False  False
# 30293      182078  True  False  False  False  False  False  False  False
# 30294      134070  True  False  False  False  False  False  False  False
# 30295       86859  True  False  False  False  False  False  False  False
# 30296       89566  True  False  False  False  False  False  False  False
# 30297       81866  True  False  False  False  False  False  False  False
# 30298      146952  True  False  False  False  False  False  False  False
# 30299      136521  True  False  False  False  False  False  False  False
# 30301      121002  True  False  False  False  False  False  False  False
# 30302      245138  True  False  False  False  False  False  False  False
# 30303      260010  True  False  False  False  False  False  False  False
# 30304      578875  True  False  False  False  False  False  False  False
# 30305      335660  True  False  False  False  False  False  False  False
# 30306      413794  True  False  False  False  False  False  False  False
# 30307      224023  True  False  False  False  False  False  False  False
# 30308      156521  True  False  False  False  False  False  False  False
# 30309      393460  True  False  False  False  False  False  False  False
# 30311      307118  True  False  False  False  False  False  False  False
# 30312      149240  True  False  False  False  False  False  False  False
# 30313      188547  True  False  False  False  False  False  False  False
# 30314       90761  True  False  False  False  False  False  False  False
# 30315       90563  True  False  False  False  False  False  False  False
# 30316       95276  True  False  False  False  False  False  False  False
# 30317      134592  True  False  False  False  False  False  False  False
# 30318       87478  True  False  False  False  False  False  False  False
# 30319      121249  True  False  False  False  False  False  False  False
# 30320      172595  True  False  False  False  False  False  False  False
# 30321      126398  True  False  False  False  False  False  False  False
# 30322       44486  True  False  False  False  False  False  False  False
# 30323      148419  True  False  False  False  False  False  False  False
#
#                       Location
# 0      (42.019063, -87.672892)
# 1      (42.015876, -87.669092)
# 2      (42.008362, -87.665909)
# 3      (42.001073, -87.661061)
# 4      (41.993664, -87.659202)
# 5      (41.990259, -87.659076)
# 6       (41.983504, -87.65884)
# 7      (41.977984, -87.658668)
# 8       (41.973453, -87.65853)
# 9      (41.969139, -87.658493)
# 10     (41.964273, -87.657588)
# 11     (41.953775, -87.654929)
# 12     (41.947428, -87.653626)
# 14     (41.925051, -87.652866)
# 15     (41.910655, -87.649177)
# 16      (41.90392, -87.631412)
# 17     (41.896671, -87.628176)
# 18     (41.891665, -87.628021)
# 19     (41.884809, -87.627813)
# 21     (41.880745, -87.627696)
# 22     (41.878153, -87.627596)
# 23     (41.874039, -87.627479)
# 25     (41.853206, -87.630968)
# 26     (41.831191, -87.630636)
# 27      (41.810318, -87.63094)
# 28      (41.79542, -87.631157)
# 29     (41.780536, -87.630952)
# 30     (41.768367, -87.625724)
# 31     (41.750419, -87.625112)
# 32     (41.735372, -87.624717)
# ...                        ...
# 30292  (41.735372, -87.624717)
# 30293  (41.750419, -87.625112)
# 30294  (41.768367, -87.625724)
# 30295  (41.780536, -87.630952)
# 30296   (41.79542, -87.631157)
# 30297   (41.810318, -87.63094)
# 30298  (41.831191, -87.630636)
# 30299  (41.853206, -87.630968)
# 30301  (41.874039, -87.627479)
# 30302  (41.878153, -87.627596)
# 30303  (41.880745, -87.627696)
# 30304  (41.884809, -87.627813)
# 30305  (41.891665, -87.628021)
# 30306  (41.896671, -87.628176)
# 30307   (41.90392, -87.631412)
# 30308  (41.910655, -87.649177)
# 30309  (41.925051, -87.652866)
# 30311  (41.947428, -87.653626)
# 30312  (41.953775, -87.654929)
# 30313  (41.964273, -87.657588)
# 30314  (41.969139, -87.658493)
# 30315   (41.973453, -87.65853)
# 30316  (41.977984, -87.658668)
# 30317   (41.983504, -87.65884)
# 30318  (41.990259, -87.659076)
# 30319  (41.993664, -87.659202)
# 30320  (42.001073, -87.661061)
# 30321  (42.008362, -87.665909)
# 30322  (42.015876, -87.669092)
# 30323  (42.019063, -87.672892)
#
# [6595 rows x 17 columns]
