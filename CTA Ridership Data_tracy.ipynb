# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
csv_file = 'cta_ridership_historical.csv'
cta_data_df = pd.read_csv(csv_file)

cta_data_df.head(20)
# Out:
#    service_date day_type      bus  rail_boardings  total_rides
# 0        1/1/01        U   297192          126455       423647
# 1        1/2/01        W   780827          501952      1282779
# 2        1/3/01        W   824923          536432      1361355
# 3        1/4/01        W   870021          550011      1420032
# 4        1/5/01        W   890426          557917      1448343
# 5        1/6/01        A   577401          255356       832757
# 6        1/7/01        U   375831          169825       545656
# 7        1/8/01        W   985221          590706      1575927
# 8        1/9/01        W   978377          599905      1578282
# 9       1/10/01        W   984884          602052      1586936
# 10      1/11/01        W   995561          607503      1603064
# 11      1/12/01        W  1018985          605252      1624237
# 12      1/13/01        A   591791          270056       861847
# 13      1/14/01        U   373091          174842       547933
# ...

# %%
#Rail Ridership Over the Years
rail_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_railriders=cta2001["rail_boardings"].sum()
rail_byyear.append(cta2001_railriders)

cta2002=cta_data_df[365:730]
cta2002_railriders=cta2002["rail_boardings"].sum()
rail_byyear.append(cta2002_railriders)


cta2003=cta_data_df[730:1095]
cta2003_railriders=cta2003["rail_boardings"].sum()
rail_byyear.append(cta2003_railriders)

cta2004=cta_data_df[1095:1461]
cta2004_railriders=cta2004["rail_boardings"].sum()
rail_byyear.append(cta2004_railriders)


cta2005=cta_data_df[1461:1826]
cta2005_railriders=cta2005["rail_boardings"].sum()
rail_byyear.append(cta2005_railriders)

cta2006=cta_data_df[1826:2191]
cta2006_railriders=cta2006["rail_boardings"].sum()
rail_byyear.append(cta2006_railriders)

cta2007=cta_data_df[2191:2556]
cta2007_railriders=cta2007["rail_boardings"].sum()
rail_byyear.append(cta2007_railriders)

cta2008=cta_data_df[2556:2922]
cta2008_railriders=cta2008["rail_boardings"].sum()
rail_byyear.append(cta2008_railriders)

cta2009=cta_data_df[2922:3287]
cta2009_railriders=cta2009["rail_boardings"].sum()
rail_byyear.append(cta2009_railriders)

cta2010=cta_data_df[3287:3652]
cta2010_railriders=cta2010["rail_boardings"].sum()
rail_byyear.append(cta2010_railriders)

cta2011=cta_data_df[3652:4048]
cta2011_railriders=cta2011["rail_boardings"].sum()
rail_byyear.append(cta2011_railriders)


cta2012=cta_data_df[4048:4414]
cta2012_railriders=cta2012["rail_boardings"].sum()
rail_byyear.append(cta2012_railriders)


cta2013=cta_data_df[4414:4779]
cta2013_railriders=cta2013["rail_boardings"].sum()
rail_byyear.append(cta2013_railriders)

cta2014=cta_data_df[4779:5175]
cta2014_railriders=cta2014["rail_boardings"].sum()
rail_byyear.append(cta2014_railriders)


cta2015=cta_data_df[5175:5540]
cta2015_railriders=cta2015["rail_boardings"].sum()
rail_byyear.append(cta2015_railriders)

cta2016=cta_data_df[5540:5906]
cta2016_railriders=cta2016["rail_boardings"].sum()
rail_byyear.append(cta2016_railriders)

cta2017=cta_data_df[5906:6271]
cta2017_railriders=cta2017["rail_boardings"].sum()
rail_byyear.append(cta2017_railriders)

x_axis=np.arange(0,len(rail_byyear))
x_years=["2001", "2002", "2003","2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012","2013", "2014", "2015", "2016", "2017"]

# %%
#Bus Ridership Over the Years
bus_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_busriders=cta2001["bus"].sum()
bus_byyear.append(cta2001_busriders)

cta2002=cta_data_df[365:730]
cta2002_busriders=cta2002["bus"].sum()
bus_byyear.append(cta2002_busriders)


cta2003=cta_data_df[730:1095]
cta2003_busriders=cta2003["bus"].sum()
bus_byyear.append(cta2003_busriders)

cta2004=cta_data_df[1095:1461]
cta2004_busriders=cta2004["bus"].sum()
bus_byyear.append(cta2004_busriders)


cta2005=cta_data_df[1461:1826]
cta2005_busriders=cta2005["bus"].sum()
bus_byyear.append(cta2005_busriders)

cta2006=cta_data_df[1826:2191]
cta2006_busriders=cta2006["bus"].sum()
bus_byyear.append(cta2006_busriders)

cta2007=cta_data_df[2191:2556]
cta2007_busriders=cta2007["bus"].sum()
bus_byyear.append(cta2007_busriders)

cta2008=cta_data_df[2556:2922]
cta2008_busriders=cta2008["bus"].sum()
bus_byyear.append(cta2008_busriders)

cta2009=cta_data_df[2922:3287]
cta2009_busriders=cta2009["bus"].sum()
bus_byyear.append(cta2009_busriders)

cta2010=cta_data_df[3287:3652]
cta2010_busriders=cta2010["bus"].sum()
bus_byyear.append(cta2010_busriders)

cta2011=cta_data_df[3652:4048]
cta2011_busriders=cta2011["bus"].sum()
bus_byyear.append(cta2011_busriders)


cta2012=cta_data_df[4048:4414]
cta2012_busriders=cta2012["bus"].sum()
bus_byyear.append(cta2012_busriders)


cta2013=cta_data_df[4414:4779]
cta2013_busriders=cta2013["bus"].sum()
bus_byyear.append(cta2013_busriders)

cta2014=cta_data_df[4779:5175]
cta2014_busriders=cta2014["bus"].sum()
bus_byyear.append(cta2014_busriders)


cta2015=cta_data_df[5175:5540]
cta2015_busriders=cta2015["bus"].sum()
bus_byyear.append(cta2015_busriders)

cta2016=cta_data_df[5540:5906]
cta2016_busriders=cta2016["bus"].sum()
bus_byyear.append(cta2016_busriders)

cta2017=cta_data_df[5906:6271]
cta2017_busriders=cta2017["bus"].sum()
bus_byyear.append(cta2017_busriders)

# %%
totalriders_byyear=[]
cta2001=cta_data_df.head(365)
cta2001_totalriders=cta2001["total_rides"].sum()
totalriders_byyear.append(cta2001_totalriders)

cta2002=cta_data_df[365:730]
cta2002_totalriders=cta2002["total_rides"].sum()
totalriders_byyear.append(cta2002_totalriders)


cta2003=cta_data_df[730:1095]
cta2003_totalriders=cta2003["total_rides"].sum()
totalriders_byyear.append(cta2003_totalriders)

cta2004=cta_data_df[1095:1461]
cta2004_totalriders=cta2004["total_rides"].sum()
totalriders_byyear.append(cta2004_totalriders)


cta2005=cta_data_df[1461:1826]
cta2005_totalriders=cta2005["total_rides"].sum()
totalriders_byyear.append(cta2005_totalriders)

cta2006=cta_data_df[1826:2191]
cta2006_totalriders=cta2006["total_rides"].sum()
totalriders_byyear.append(cta2006_totalriders)

cta2007=cta_data_df[2191:2556]
cta2007_totalriders=cta2007["total_rides"].sum()
totalriders_byyear.append(cta2007_totalriders)

cta2008=cta_data_df[2556:2922]
cta2008_totalriders=cta2008["total_rides"].sum()
totalriders_byyear.append(cta2008_totalriders)

cta2009=cta_data_df[2922:3287]
cta2009_totalriders=cta2009["total_rides"].sum()
totalriders_byyear.append(cta2009_totalriders)

cta2010=cta_data_df[3287:3652]
cta2010_totalriders=cta2010["total_rides"].sum()
totalriders_byyear.append(cta2010_totalriders)

cta2011=cta_data_df[3652:4048]
cta2011_totalriders=cta2011["total_rides"].sum()
totalriders_byyear.append(cta2011_totalriders)


cta2012=cta_data_df[4048:4414]
cta2012_totalriders=cta2012["total_rides"].sum()
totalriders_byyear.append(cta2012_totalriders)


cta2013=cta_data_df[4414:4779]
cta2013_totalriders=cta2013["total_rides"].sum()
totalriders_byyear.append(cta2013_totalriders)

cta2014=cta_data_df[4779:5175]
cta2014_totalriders=cta2014["total_rides"].sum()
totalriders_byyear.append(cta2014_totalriders)


cta2015=cta_data_df[5175:5540]
cta2015_totalriders=cta2015["total_rides"].sum()
totalriders_byyear.append(cta2015_totalriders)

cta2016=cta_data_df[5540:5906]
cta2016_totalriders=cta2016["total_rides"].sum()
totalriders_byyear.append(cta2016_totalriders)

cta2017=cta_data_df[5906:6271]
cta2017_totalriders=cta2017["total_rides"].sum()
totalriders_byyear.append(cta2017_totalriders)

total, =plt.plot(x_axis, totalriders_byyear, color="red", label="total")
bus,=plt.plot(x_axis, bus_byyear, color="blue", label="bus")
rail, =plt.plot(x_axis, rail_byyear, color="green",label="rail")
plt.xticks(x_axis,x_years, rotation ="vertical")
plt.title("CTA Ridership Over the Years")
plt.legend(handles= [total, bus, rail], loc="upper left")

# %%
x_axis0 = cta_data_df['day_type']
plt.bar(x_axis0, cta_data_df['total_rides'])
plt.show()

# %%
csv_file = 'newer.csv'
cta_month = pd.read_csv(csv_file)

#Sorting by each line
red=cta_month.loc[cta_month["RED"]==True]
blue=cta_month.loc[cta_month["BLUE"]==True]
green=cta_month.loc[cta_month["G"]==True]
brown=cta_month.loc[cta_month["BRN"]==True]
yellow=cta_month.loc[cta_month["Y"]==True]
pink=cta_month.loc[cta_month["Pnk"]==True]
orange=cta_month.loc[cta_month["O"]==True]
purple=cta_month.loc[cta_month["P"]==True]

# %%
#RED 
#1.binning the data into 3 year ranges
red["year"]=red["month_beginning"].str[-4 :]
red["year"]=pd.to_numeric(red["year"])
bins=[2000,2006.5,2012.5,2017.5]
group_names=["2001-2006","2007-2012","2012-2017"]
red["YearBins"]=pd.cut(red["year"], bins, labels=group_names)

#2. Finding the total ridership of each station, grouped by year ranges
red_bystation=red.groupby(["YearBins","stationame"]).sum()
red_bystation["BinTotal"]=red_bystation["monthtotal"]

#3. Dropping all other useless columns 
red_bystation.drop("Unnamed: 0", axis=1, inplace=True)
red_bystation.drop("MAP_ID", axis=1, inplace=True)
red_bystation.drop("avg_weekday_rides", axis=1, inplace=True)
red_bystation.drop("avg_saturday_rides", axis=1, inplace=True)
red_bystation.drop("avg_sunday-holiday_rides", axis=1, inplace=True)
red_bystation.drop("monthtotal", axis=1, inplace=True)
red_bystation.drop("year", axis=1, inplace=True)

#4.Finding out stations with the most riders, grouped by year ranges
red_bystation=red_bystation.sort_values(["YearBins", "BinTotal"], ascending=[True,False])


red_bystation_overyear=red_bystation.unstack(0)

change=[]
change=red_bystation_overyear["BinTotal"]["2012-2017"]-red_bystation_overyear["BinTotal"]["2001-2006"]
change.sort_values(ascending=False)

total=[]
total=red_bystation_overyear["BinTotal"]["2012-2017"]+red_bystation_overyear["BinTotal"]["2007-2012"]+red_bystation_overyear["BinTotal"]["2001-2006"]
total.sort_values(ascending=False)                                                                                     
                                                                                      
summary=pd.DataFrame({"change": change, "total": total})
red_combined=pd.merge(red_bystation_overyear, summary,on="stationame", how="outer")
red_combined.sort_values("change", ascending=False)                                                                            


red_combined.sum()
red_change=[341332796, 377529533,333383814]

red_bystation.sum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#BLUE 
#1.binning the data into 3 year ranges
blue["year"]=blue["month_beginning"].str[-4 :]
blue["year"]=pd.to_numeric(blue["year"])
bins=[2000,2006.5,2012.5,2017.5]
group_names=["2001-2006","2007-2012","2012-2017"]
blue["YearBins"]=pd.cut(blue["year"], bins, labels=group_names)

#2. Finding the total ridership of each station, grouped by year ranges
blue_bystation=blue.groupby(["YearBins","stationame"]).sum()
blue_bystation["BinTotal"]=blue_bystation["monthtotal"]

#3. Dropping all other useless columns 
blue_bystation.drop("Unnamed: 0", axis=1, inplace=True)
blue_bystation.drop("MAP_ID", axis=1, inplace=True)
blue_bystation.drop("avg_weekday_rides", axis=1, inplace=True)
blue_bystation.drop("avg_saturday_rides", axis=1, inplace=True)
blue_bystation.drop("avg_sunday-holiday_rides", axis=1, inplace=True)
blue_bystation.drop("monthtotal", axis=1, inplace=True)
blue_bystation.drop("year", axis=1, inplace=True)

#4.Finding out stations with the most riders, grouped by year ranges
blue_bystation=blue_bystation.sort_values(["YearBins", "BinTotal"], ascending=[True,False])
blue_bystation


blue_bystation_overyear=blue_bystation.unstack(0)

change=[]
change=blue_bystation_overyear["BinTotal"]["2012-2017"]-blue_bystation_overyear["BinTotal"]["2001-2006"]
change.sort_values(ascending=False)

total=[]
total=blue_bystation_overyear["BinTotal"]["2012-2017"]+blue_bystation_overyear["BinTotal"]["2007-2012"]+blue_bystation_overyear["BinTotal"]["2001-2006"]
total.sort_values(ascending=False)                                                                                     
                                                                                      
summary=pd.DataFrame({"change": change, "total": total})
blue_combined=pd.merge(blue_bystation_overyear, summary,on="stationame", how="outer")
blue_combined.sort_values("change", ascending=False) 


blue_combined.sum()
blue_change=[205512796,226248515,227407973]
blue_bystation.sum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#Orange
#1.binning the data into 3 year ranges
orange["year"]=orange["month_beginning"].str[-4 :]
orange["year"]=pd.to_numeric(orange["year"])
bins=[2000,2006.5,2012.5,2017.5]
group_names=["2001-2006","2007-2012","2012-2017"]
orange["YearBins"]=pd.cut(orange["year"], bins, labels=group_names)

#2. Finding the total ridership of each station, grouped by year ranges
orange_bystation=orange.groupby(["YearBins","stationame"]).sum()
orange_bystation["BinTotal"]=orange_bystation["monthtotal"]

#3. Dropping all other useless columns 
orange_bystation.drop("Unnamed: 0", axis=1, inplace=True)
orange_bystation.drop("MAP_ID", axis=1, inplace=True)
orange_bystation.drop("avg_weekday_rides", axis=1, inplace=True)
orange_bystation.drop("avg_saturday_rides", axis=1, inplace=True)
orange_bystation.drop("avg_sunday-holiday_rides", axis=1, inplace=True)
orange_bystation.drop("monthtotal", axis=1, inplace=True)
orange_bystation.drop("year", axis=1, inplace=True)

#4.Finding out stations with the most riders, grouped by year ranges
orange_bystation=orange_bystation.sort_values(["YearBins", "BinTotal"], ascending=[True,False])
orange_bystation


orange_bystation_overyear=orange_bystation.unstack(0)

change=[]
change=orange_bystation_overyear["BinTotal"]["2012-2017"]-orange_bystation_overyear["BinTotal"]["2001-2006"]
change.sort_values(ascending=False)

total=[]
total=orange_bystation_overyear["BinTotal"]["2012-2017"]+orange_bystation_overyear["BinTotal"]["2007-2012"]+orange_bystation_overyear["BinTotal"]["2001-2006"]
total.sort_values(ascending=False)                                                                                     
                                                                                      
summary=pd.DataFrame({"change": change, "total": total})
orange_combined=pd.merge(orange_bystation_overyear, summary,on="stationame", how="outer")
orange_combined.sort_values("change", ascending=False)                    

orange_combined.sum()
orange_change=[119058743,138663010,127460857]
orange_bystation.sum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#Purple
#1.binning the data into 3 year ranges
purple["year"]=purple["month_beginning"].str[-4 :]
purple["year"]=pd.to_numeric(purple["year"])
bins=[2000,2006.5,2012.5,2017.5]
group_names=["2001-2006","2007-2012","2012-2017"]
purple["YearBins"]=pd.cut(purple["year"], bins, labels=group_names)

#2. Finding the total ridership of each station, grouped by year ranges
purple_bystation=purple.groupby(["YearBins","stationame"]).sum()
purple_bystation["BinTotal"]=purple_bystation["monthtotal"]

#3. Dropping all other useless columns 
purple_bystation.drop("Unnamed: 0", axis=1, inplace=True)
purple_bystation.drop("MAP_ID", axis=1, inplace=True)
purple_bystation.drop("avg_weekday_rides", axis=1, inplace=True)
purple_bystation.drop("avg_saturday_rides", axis=1, inplace=True)
purple_bystation.drop("avg_sunday-holiday_rides", axis=1, inplace=True)
purple_bystation.drop("monthtotal", axis=1, inplace=True)
purple_bystation.drop("year", axis=1, inplace=True)

#4.Finding out stations with the most riders, grouped by year ranges
purple_bystation=purple_bystation.sort_values(["YearBins", "BinTotal"], ascending=[True,False])
purple_bystation



purple_bystation_overyear=purple_bystation.unstack(0)

change=[]
change=purple_bystation_overyear["BinTotal"]["2012-2017"]-purple_bystation_overyear["BinTotal"]["2001-2006"]
change.sort_values(ascending=False)

total=[]
total=purple_bystation_overyear["BinTotal"]["2012-2017"]+purple_bystation_overyear["BinTotal"]["2007-2012"]+purple_bystation_overyear["BinTotal"]["2001-2006"]
total.sort_values(ascending=False)                                                                                     
                                                                                      
summary=pd.DataFrame({"change": change, "total": total})
purple_combined=pd.merge(purple_bystation_overyear, summary,on="stationame", how="outer")
purple_combined.sort_values("change", ascending=False)          


purple_combined.sum()
purple_change=[18328598,19033282,16317447]
purple_bystation.sum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#Ridership Change of the 4 lines Over the Years
x_axis1=np.arange(0, len(red_change))
redline, =plt.plot(x_axis1, red_change, color="red", alpha=0.5, label="red")
blueline, =plt.plot(x_axis1, blue_change, color="blue", alpha=0.5,label="blue")
orangeline, =plt.plot(x_axis1, orange_change, color="orange", label="orange")
purpleline, =plt.plot(x_axis1, purple_change, color="purple", alpha=0.5, label="purple")

labels=["2001-2006","2007-2012","2012-2017"]
plt.xticks(x_axis1,labels )
plt.legend(handles= [redline, blueline, orangeline,purpleline], loc="upper right")
plt.title("CTA Ridership Change Over the Years")
plt.ylabel("Number of Riders (10 Millions)")
plt.xlabel("Year")
plt.savefig("CTA Ridership Change")

# %%
popularity=[1052246143,659169284,385182610,53679327]
x_axis2=np.arange(0,len(popularity),1)
bars=plt.bar(x_axis2, popularity, alpha=0.5, align="center")

tic=[value for value in x_axis2]
label=["Red","Blue","Orange","Purple"]
plt.xticks(tic, label)
bars[0].set_color('r')
bars[2].set_color('orange')
bars[3].set_color('purple')
plt.title("Overall Popularity of CTA Lines")
plt.ylabel("Number of Riders (Billions)")
plt.xlabel("Lines")
plt.savefig("Overall Popularity of CTA Lines")
